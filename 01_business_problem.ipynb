# %% [markdown]
# ### What is customer churn?

# %% [markdown]
# Customer churn is the lose of relationship between consumer and company. Churn predicts those customers who are going to break the relationship with the company and and at what time. And it will also predicts the issues/problems that customers are facing which is infact the root cause for ending the relationship.

# %% [markdown]
# ### Why is customer churn a BUSINESS problem and not just a data problem?

# %% [markdown]
# Customer chirn is a Business problem rather than data problem. Beacause it can predict most accurate revenue lose, growth rate, what type of customers are moving out of the companies ecosystem or relationship break, what type of services/products the company is good at and there contribution in revenue and profit, and because of what services/products company is holding back.

# %% [markdown]
# ### What exact decision will this project help the company make?

# %% [markdown]
# This project helps the company to understand the root cause that is faced by the customers who are breaking the relationship with the company. It can also predict the revenue lose, what are the issues that are holding back the company, it can predict what type of customers the company sholud target, predict growth rate, etc.

# %% [markdown]
# ### Who is the end user of this analysis or model?

# %% [markdown]
# The end users of this analysis/model are sr.management/higher ups of the company who are responsible for running the company/team/department. They will use these analysis prediction and reslove the issues in the company to increase revenue, growth rate. They use the churn to understand the business and can able to resturcture the business policies and etc.

# %% [markdown]
# ### What is worse for the business in churn prediction?

# %% [markdown]
# The most worse is False negative. Because of it the company can't able to tell how the revenue is tarvelling, issues for customers lose, it can't be a much of a help for sr.management, the company can't able to know with what type of customers they should travle with.
